# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import regex as re

# %%
df_item = pd.read_csv('/workspaces/ftu_ds_comp/data/03_Item_Information_Data.csv')
df_cust = pd.read_csv('/workspaces/ftu_ds_comp/data/03_Customer_Behavior_Data.csv')
df_shelf = pd.read_csv('/workspaces/ftu_ds_comp/data/03_Shelf_Information_Data.csv')

# %%
des_shelf = pd.read_excel('/workspaces/ftu_ds_comp/data/02_DataDescription.xlsx',0)
des_item = pd.read_excel('/workspaces/ftu_ds_comp/data/02_DataDescription.xlsx',1)
des_cus = pd.read_excel('/workspaces/ftu_ds_comp/data/02_DataDescription.xlsx',2)
des_join= pd.concat([des_item,pd.DataFrame({np.nan: np.nan*des_item.shape[1]},index=[0]),des_cus,pd.DataFrame({np.nan: np.nan*des_item.shape[1]},index=[0]), des_shelf ], axis=0).to_csv('description.txt', sep='\t', index=False)

# %%
print(df_item.shape, df_item.columns.to_list())
print(df_cust.shape,df_cust.columns.to_list())
print(df_shelf.shape,df_shelf.columns.to_list())
# Out:
# (134, 12) ['Shelf ID', 'Item ID', 'Name', 'Origin', 'Location', 'Weight (g)', 'Price', 'NSX', 'HSD', 'Marketing strategy', 'Discount ', 'Rate']
# (15394, 18) ['Shelf ID', 'Person ID', 'Timestamp', 'Age', 'Gender', 'Height', 'Weight', 'Married status', 'Moving speed (m/s)', 'Item ID', 'Looking at item (s)', 'Holding the item (s)', 'Holding the bag', 'Picking up item', 'Returning item', 'Putting item into bag', 'Taking item out of bag', 'Putting item into bag in the 2nd time']
# (8, 9) ['Shelf ID', 'Description', 'Location_x (center)', 'Location_y (center)', 'Width', 'Height', 'Length', 'Number of items', 'Shape']

# %% [markdown]
# ____
# ## Data cleaning

# %% [markdown]
# ### 1. df_item
#
# - 134 rows
# - 12 columms

# %%
df_item.head(5)
# Out:
#    Shelf ID  Item ID                       Name    Origin    Location  \
# 0         0        0                  Bánh Oreo   Vietnam         Cao
# 1         0        1              Bánh Chocopie   Vietnam         Cao
# 2         0        2  Kẹo cao su Cool Air Fresh   Vietnam  Trung bình
# 3         0        3   Bánh mỳ chà bông Kinh đô   Vietnam  Trung bình
# 4         0        4         Bánh trứng Custard  Thái Lan  Trung bình
#
#    Weight (g)     Price         NSX         HSD  Marketing strategy  \
# 0       120.0  17,500 ₫  2023-11-14  2024-10-17               False
# 1       396.0  48,000 ₫  2023-10-07  2024-09-16               False
# 2        40.0  40,000 ₫  2024-06-02  2026-06-02               False
# 3        80.0  13,400 ₫  2024-05-02  2026-05-02               False
# 4        46.0  17,000 ₫  2023-10-30  2024-04-16                True
#
#    Discount   Rate
# 0         10     4
# 1          0     3
# 2          0     3
# 3          0     3
# 4         10     4

# %%
print(df_item.describe(), df_item.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Shelf ID            134 non-null    int64
#  1   Item ID             134 non-null    int64
#  2   Name                134 non-null    object
#  3   Origin              134 non-null    object
#  4   Location            134 non-null    object
#  5   Weight (g)          110 non-null    float64
#  6   Price               134 non-null    object
#  7   NSX                 100 non-null    object
#  8   HSD                 100 non-null    object
#  9   Marketing strategy  134 non-null    bool
#  10  Discount            134 non-null    int64
#  11  Rate                134 non-null    int64
# dtypes: bool(1), float64(1), int64(4), object(6)
# memory usage: 11.8+ KB
#          Shelf ID     Item ID   Weight (g)   Discount         Rate
# count  134.000000  134.000000   110.000000  134.000000  134.000000
# mean     3.634328    8.440299   489.650000    6.291045    3.791045
# std      2.202326    5.730162   682.200963    8.736601    0.756671
# min      0.000000    0.000000     2.000000    0.000000    3.000000
# 25%      2.000000    4.000000    92.500000    0.000000    3.000000
# 50%      4.000000    8.000000   310.000000    0.000000    4.000000
# 75%      5.750000   12.750000   600.000000   10.000000    4.000000
# max      7.000000   24.000000  5000.000000   30.000000    5.000000 None

# %% [markdown]
# #### TODO:
# - convert NSX, HSD -> datetime
# - clean Price to int + rename col to price_vnd
# - change all name to camel case & lowercase

# %%
df_item['NSX'] = pd.to_datetime(df_item['NSX'], format='%Y-%m-%d', errors='ignore') # covert to date_time  
df_item['HSD'] = pd.to_datetime(df_item['HSD'], format='%Y-%m-%d', errors='ignore') # covert to date_time
# Out:
# /tmp/ipykernel_5304/1590734509.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   df_item['NSX'] = pd.to_datetime(df_item['NSX'], format='%Y-%m-%d', errors='ignore') # covert to date_time
# /tmp/ipykernel_5304/1590734509.py:2: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   df_item['HSD'] = pd.to_datetime(df_item['HSD'], format='%Y-%m-%d', errors='ignore') # covert to date_time

# %%
df_item.loc[:,'Price'] = df_item.Price.replace(regex=r'\D+', value='') # clean to int char
df_item.rename(columns={'Price': 'Price_vnd'}, inplace=True)
df_item['Price_vnd'] = pd.to_numeric(df_item['Price_vnd'],errors='coerce') # convert to numeric

# %%
df_item_col = df_item.columns.to_list()
df_item_col_new={col:re.sub(' ','_', col.strip()).lower() for col in df_item_col}
df_item.rename(columns=df_item_col_new,inplace=True)

# %%
df_item.head(5)
# Out:
#    shelf_id  item_id                       name    origin    location  \
# 0         0        0                  Bánh Oreo   Vietnam         Cao
# 1         0        1              Bánh Chocopie   Vietnam         Cao
# 2         0        2  Kẹo cao su Cool Air Fresh   Vietnam  Trung bình
# 3         0        3   Bánh mỳ chà bông Kinh đô   Vietnam  Trung bình
# 4         0        4         Bánh trứng Custard  Thái Lan  Trung bình
#
#    weight_(g)  price_vnd        nsx        hsd  marketing_strategy  discount  \
# 0       120.0      17500 2023-11-14 2024-10-17               False        10
# 1       396.0      48000 2023-10-07 2024-09-16               False         0
# 2        40.0      40000 2024-06-02 2026-06-02               False         0
# 3        80.0      13400 2024-05-02 2026-05-02               False         0
# 4        46.0      17000 2023-10-30 2024-04-16                True        10
#
#    rate
# 0     4
# 1     3
# 2     3
# 3     3
# 4     4

# %%
print(df_item.describe(), df_item.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   shelf_id            134 non-null    int64
#  1   item_id             134 non-null    int64
#  2   name                134 non-null    object
#  3   origin              134 non-null    object
#  4   location            134 non-null    object
#  5   weight_(g)          110 non-null    float64
#  6   price_vnd           134 non-null    int64
#  7   nsx                 100 non-null    datetime64[ns]
#  8   hsd                 100 non-null    datetime64[ns]
#  9   marketing_strategy  134 non-null    bool
#  10  discount            134 non-null    int64
#  11  rate                134 non-null    int64
# dtypes: bool(1), datetime64[ns](2), float64(1), int64(5), object(3)
# memory usage: 11.8+ KB
#          shelf_id     item_id   weight_(g)     price_vnd                  nsx  \
# count  134.000000  134.000000   110.000000  1.340000e+02                  100
# mean     3.634328    8.440299   489.650000  1.512963e+05  2024-01-23 14:24:00
# min      0.000000    0.000000     2.000000  4.400000e+03  2023-08-11 00:00:00
# 25%      2.000000    4.000000    92.500000  2.510000e+04  2023-10-18 06:00:00
# 50%      4.000000    8.000000   310.000000  4.750000e+04  2024-01-04 12:00:00
# 75%      5.750000   12.750000   600.000000  1.387500e+05  2024-04-23 06:00:00
# max      7.000000   24.000000  5000.000000  1.600000e+06  2024-08-05 00:00:00
# std      2.202326    5.730162   682.200963  2.710174e+05                  NaN
#
#                        hsd    discount        rate
# count                  100  134.000000  134.000000
# mean   2024-08-20 15:07:12    6.291045    3.791045
# min    2023-11-02 00:00:00    0.000000    3.000000
# 25%    2024-04-13 12:00:00    0.000000    3.000000
# 50%    2024-08-18 12:00:00    0.000000    4.000000
# 75%    2024-10-31 18:00:00   10.000000    4.000000
# max    2026-06-02 00:00:00   30.000000    5.000000
# std                    NaN    8.736601    0.756671   None

# %% [markdown]
# #### EDA of df_item:
# > 34 NSX , 34 HSD nulls, 24 weight_(g) nulls
# - fill in strategy:
# - - NSX & HSD: leave as is
# - - weight: leave as is

# %%
df_item['si_id']= df_item['shelf_id'].astype(str) + df_item['item_id'].astype(str)
df_item.nunique().to_dict()
# Out:
# {'shelf_id': 8,
#  'item_id': 25,
#  'name': 134,
#  'origin': 11,
#  'location': 3,
#  'weight_(g)': 58,
#  'price_vnd': 109,
#  'nsx': 82,
#  'hsd': 90,
#  'marketing_strategy': 2,
#  'discount': 9,
#  'rate': 3,
#  'si_id': 134}

# %%
df_item
# Out:
#      shelf_id  item_id                       name    origin    location  \
# 0           0        0                  Bánh Oreo   Vietnam         Cao
# 1           0        1              Bánh Chocopie   Vietnam         Cao
# 2           0        2  Kẹo cao su Cool Air Fresh   Vietnam  Trung bình
# 3           0        3   Bánh mỳ chà bông Kinh đô   Vietnam  Trung bình
# 4           0        4         Bánh trứng Custard  Thái Lan  Trung bình
# ..        ...      ...                        ...       ...         ...
# 129         7       11              Pizza kitkool   Vietnam        Thấp
# 130         7       12               Mý ý SG Food   Vietnam        Thấp
# 131         7       13            Thanh cua Akira  Nhật Bản        Thấp
# 132         7       14            Nước lẩu Barona   Vietnam        Thấp
# 133         7       15                Xúc xích CP   Vietnam        Thấp
#
#      weight_(g)  price_vnd        nsx        hsd  marketing_strategy  \
# 0         120.0      17500 2023-11-14 2024-10-17               False
# 1         396.0      48000 2023-10-07 2024-09-16               False
# 2          40.0      40000 2024-06-02 2026-06-02               False
# 3          80.0      13400 2024-05-02 2026-05-02               False
# 4          46.0      17000 2023-10-30 2024-04-16                True
# ..          ...        ...        ...        ...                 ...
# 129       140.0      33000 2024-04-16 2024-06-10               False
# 130       250.0      27000 2024-02-05 2024-09-03               False
# 131       200.0      58500 2023-10-16 2023-12-19               False
# 132       180.0      32000 2023-12-02 2024-03-02               False
# 133       450.0      94000 2024-02-21 2024-05-23               False
#
#      discount  rate si_id
# 0          10     4    00
# 1           0     3    01
# 2           0     3    02
# 3           0     3    03
# 4          10     4    04
# ..        ...   ...   ...
# 129         0     4   711
# 130         0     4   712
# 131         0     4   713
# 132         0     4   714
# 133         0     4   715
#
# [134 rows x 13 columns]

# %% [markdown]
# ### 2. df_cust
# - 15394 rows
# - 18 columms

# %%
df_cust.head(5)
# Out:
#    Shelf ID  Person ID   Timestamp  Age  Gender  Height  Weight  \
# 0         4          1  1720260000   52  Female     162      41
# 1         4          1  1720260120   52  Female     162      41
# 2         4          1  1720260300   52  Female     162      41
# 3         4          1  1720260360   52  Female     162      41
# 4         4          1  1720260480   52  Female     162      41
#
#   Married status  Moving speed (m/s)  Item ID  Looking at item (s)  \
# 0        Married                0.19       16                   27
# 1        Married                0.49        5                   22
# 2        Married                0.36        4                   25
# 3        Married                0.64        8                   21
# 4        Married                0.13        6                   27
#
#    Holding the item (s)  Holding the bag  Picking up item  Returning item  \
# 0                    36             True             True           False
# 1                    17             True             True           False
# 2                    39             True             True            True
# 3                    35             True             True            True
# 4                    16             True             True           False
#
#   Putting item into bag Taking item out of bag  \
# 0                 False                  False
# 1                  True                   True
# 2                  True                   True
# 3                 False                  False
# 4                 False                  False
#
#   Putting item into bag in the 2nd time
# 0                                  True
# 1                                  True
# 2                                 False
# 3                                 False
# 4                                  True

# %%
df_cust.describe()
# Out:
#            Shelf ID     Person ID     Timestamp           Age        Height  \
# count  15394.000000  15394.000000  1.539400e+04  15394.000000  15394.000000
# mean       3.316942    733.690984  1.720211e+09     46.198064    164.719826
# std        2.580487    429.865481  1.567575e+05     16.991954      9.880132
# min        0.000000      1.000000  1.719828e+09     18.000000    147.000000
# 25%        1.000000    360.000000  1.720109e+09     31.000000    156.000000
# 50%        3.000000    718.000000  1.720261e+09     45.000000    166.000000
# 75%        6.000000   1105.000000  1.720326e+09     62.000000    174.000000
# max        7.000000   1500.000000  1.720459e+09     75.000000    179.000000
#
#              Weight  Moving speed (m/s)       Item ID  Looking at item (s)  \
# count  15394.000000        15394.000000  15394.000000         15394.000000
# mean      60.015720            0.803467      7.563206            28.699948
# std       14.068385            0.403269      5.190824            12.596675
# min       40.000000            0.100000      0.000000             0.000000
# 25%       48.000000            0.460000      3.000000            20.000000
# 50%       57.000000            0.810000      7.000000            27.000000
# 75%       71.000000            1.150000     11.000000            35.000000
# max       89.000000            1.500000     24.000000            69.000000
#
#        Holding the item (s)
# count          15394.000000
# mean              27.087502
# std               10.249892
# min                0.000000
# 25%               20.000000
# 50%               27.000000
# 75%               34.000000
# max               59.000000

# %%
df_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15394 entries, 0 to 15393
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Shelf ID                               15394 non-null  int64
#  1   Person ID                              15394 non-null  int64
#  2   Timestamp                              15394 non-null  int64
#  3   Age                                    15394 non-null  int64
#  4   Gender                                 15394 non-null  object
#  5   Height                                 15394 non-null  int64
#  6   Weight                                 15394 non-null  int64
#  7   Married status                         15394 non-null  object
#  8   Moving speed (m/s)                     15394 non-null  float64
#  9   Item ID                                15394 non-null  int64
#  10  Looking at item (s)                    15394 non-null  int64
#  11  Holding the item (s)                   15394 non-null  int64
#  12  Holding the bag                        15394 non-null  bool
#  13  Picking up item                        15394 non-null  bool
#  14  Returning item                         15394 non-null  bool
#  15  Putting item into bag                  14056 non-null  object
#  16  Taking item out of bag                 13452 non-null  object
#  17  Putting item into bag in the 2nd time  12723 non-null  object
# dtypes: bool(3), float64(1), int64(9), object(5)
# memory usage: 1.8+ MB

# %% [markdown]
# ### TODO:
# - change all name to camel case & lowercase
# - null of 3 columns:
#
#     15  Putting item into bag                  14056 non-null  object
#
#     16  Taking item out of bag                 13452 non-null  object
#
#     17  Putting item into bag in the 2nd time  12723 non-null  object
# - clean Timestamp to datetime[ns] (currently Epoch time(?))
# - create pk si_id
# - hot-one enconding gender , married status

# %%
df_cust_col = df_cust.columns.to_list()
df_cust_col_new={col:re.sub(' ','_', col.strip()).lower() for col in df_cust_col}
df_cust.rename(columns=df_cust_col_new,inplace=True)
df_cust['si_id']= df_cust['shelf_id'].astype(str) + df_cust['item_id'].astype(str)

# %%
df_cust.nunique()
# Out:
# shelf_id                                    8
# person_id                                1500
# timestamp                                6491
# age                                        58
# gender                                      2
# height                                     32
# weight                                     50
# married_status                              2
# moving_speed_(m/s)                        141
# item_id                                    25
# looking_at_item_(s)                        60
# holding_the_item_(s)                       50
# holding_the_bag                             2
# picking_up_item                             2
# returning_item                              2
# putting_item_into_bag                       2
# taking_item_out_of_bag                      2
# putting_item_into_bag_in_the_2nd_time       2
# si_id                                     134
# dtype: int64

# %%
print(df_cust.isnull().sum()[df_cust.isnull().sum() > 0].to_dict()) # 5951 / 5081
# Out:
# {'putting_item_into_bag': 1338, 'taking_item_out_of_bag': 1942, 'putting_item_into_bag_in_the_2nd_time': 2671}

# %%
df_cust['timestamp']=pd.to_datetime(df_cust['timestamp'], unit='s')
df_cust['date'] = df_cust['timestamp'].dt.date  # YYYY-MM-DD
df_cust['time'] = df_cust['timestamp'].dt.time ## HH:MM:SS
df_cust.sort_values(by='timestamp',ascending=False).head(5) # latest 2024-07-08 17:21:00
df_cust.sort_values(by='timestamp',ascending=True).head(5) # earliest 2024-07-01 10:00:00
# Out:
#       shelf_id  person_id           timestamp  age  gender  height  weight  \
# 8808         6        827 2024-07-01 10:00:00   30  Female     149      45
# 8809         6        827 2024-07-01 10:03:00   30  Female     149      45
# 8810         4        828 2024-07-01 10:03:00   42    Male     176      76
# 8811         4        828 2024-07-01 10:05:00   42    Male     176      76
# 8812         4        828 2024-07-01 10:09:00   42    Male     176      76
#
#      married_status  moving_speed_(m/s)  item_id  ...  holding_the_item_(s)  \
# 8808         Single                0.17        0  ...                     5
# 8809         Single                1.31       15  ...                     3
# 8810        Married                0.80       10  ...                    17
# 8811        Married                0.34       14  ...                    27
# 8812        Married                1.38        2  ...                    37
#
#       holding_the_bag  picking_up_item  returning_item  putting_item_into_bag  \
# 8808            False             True            True                   True
# 8809            False             True           False                  False
# 8810             True             True           False                   True
# 8811             True             True           False                   True
# 8812             True             True            True                   True
#
#      taking_item_out_of_bag putting_item_into_bag_in_the_2nd_time si_id  \
# 8808                    NaN                                  True    60
# 8809                  False                                  True   615
# 8810                  False                                 False   410
# 8811                   True                                 False   414
# 8812                  False                                  True    42
#
#             date      time
# 8808  2024-07-01  10:00:00
# 8809  2024-07-01  10:03:00
# 8810  2024-07-01  10:03:00
# 8811  2024-07-01  10:05:00
# 8812  2024-07-01  10:09:00
#
# [5 rows x 21 columns]

# %%
df_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15394 entries, 0 to 15393
# Data columns (total 21 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   shelf_id                               15394 non-null  int64
#  1   person_id                              15394 non-null  int64
#  2   timestamp                              15394 non-null  datetime64[ns]
#  3   age                                    15394 non-null  int64
#  4   gender                                 15394 non-null  object
#  5   height                                 15394 non-null  int64
#  6   weight                                 15394 non-null  int64
#  7   married_status                         15394 non-null  object
#  8   moving_speed_(m/s)                     15394 non-null  float64
#  9   item_id                                15394 non-null  int64
#  10  looking_at_item_(s)                    15394 non-null  int64
#  11  holding_the_item_(s)                   15394 non-null  int64
#  12  holding_the_bag                        15394 non-null  bool
#  13  picking_up_item                        15394 non-null  bool
#  14  returning_item                         15394 non-null  bool
#  15  putting_item_into_bag                  14056 non-null  object
#  16  taking_item_out_of_bag                 13452 non-null  object
#  17  putting_item_into_bag_in_the_2nd_time  12723 non-null  object
#  18  si_id                                  15394 non-null  object
#  19  date                                   15394 non-null  object
#  20  time                                   15394 non-null  object
# dtypes: bool(3), datetime64[ns](1), float64(1), int64(8), object(8)
# memory usage: 2.2+ MB

# %% [markdown]
# ### 2.1 Create interaction & interest ( `i_i` ) df

# %%
interact= df_cust[['si_id','shelf_id','item_id','person_id','timestamp', 'date', 'time', 'holding_the_bag','picking_up_item','returning_item'	,'putting_item_into_bag'	,'taking_item_out_of_bag'	,'putting_item_into_bag_in_the_2nd_time']]
interest=pd.concat([df_cust['holding_the_item_(s)'] >0, df_cust['looking_at_item_(s)'] >0],axis=1)
i_i=pd.concat([interact,interest],axis=1)
i_i
# Out:
#       si_id  shelf_id  item_id  person_id           timestamp        date  \
# 0       416         4       16          1 2024-07-06 10:00:00  2024-07-06
# 1        45         4        5          1 2024-07-06 10:02:00  2024-07-06
# 2        44         4        4          1 2024-07-06 10:05:00  2024-07-06
# 3        48         4        8          1 2024-07-06 10:06:00  2024-07-06
# 4        46         4        6          1 2024-07-06 10:08:00  2024-07-06
# ...     ...       ...      ...        ...                 ...         ...
# 15389    24         2        4       1500 2024-07-05 03:49:00  2024-07-05
# 15390    33         3        3       1500 2024-07-05 03:54:00  2024-07-05
# 15391   321         3       21       1500 2024-07-05 03:56:00  2024-07-05
# 15392   313         3       13       1500 2024-07-05 03:58:00  2024-07-05
# 15393    37         3        7       1500 2024-07-05 04:03:00  2024-07-05
#
#            time  holding_the_bag  picking_up_item  returning_item  \
# 0      10:00:00             True             True           False
# 1      10:02:00             True             True           False
# 2      10:05:00             True             True            True
# 3      10:06:00             True             True            True
# 4      10:08:00             True             True           False
# ...         ...              ...              ...             ...
# 15389  03:49:00            False             True           False
# 15390  03:54:00            False             True           False
# 15391  03:56:00            False             True           False
# 15392  03:58:00            False             True           False
# 15393  04:03:00            False             True           False
#
#       putting_item_into_bag taking_item_out_of_bag  \
# 0                     False                  False
# 1                      True                   True
# 2                      True                   True
# 3                     False                  False
# 4                     False                  False
# ...                     ...                    ...
# 15389                  True                   True
# 15390                  True                   True
# 15391                 False                   True
# 15392                 False                   True
# 15393                  True                   True
#
#       putting_item_into_bag_in_the_2nd_time  holding_the_item_(s)  \
# 0                                      True                  True
# 1                                      True                  True
# 2                                     False                  True
# 3                                     False                  True
# 4                                      True                  True
# ...                                     ...                   ...
# 15389                                  True                  True
# 15390                                  True                  True
# 15391                                 False                  True
# 15392                                  True                  True
# 15393                                 False                  True
#
#        looking_at_item_(s)
# 0                     True
# 1                     True
# 2                     True
# 3                     True
# 4                     True
# ...                    ...
# 15389                 True
# 15390                 True
# 15391                 True
# 15392                 True
# 15393                 True
#
# [15394 rows x 15 columns]

# %% [markdown]
# #### null of i_i

# %%
null = pd.concat([i_i.loc[i_i['putting_item_into_bag'].isnull(), :], \
    i_i.loc[i_i['taking_item_out_of_bag'].isnull(), :], \
        i_i.loc[i_i['taking_item_out_of_bag'].isnull(), :], \
            i_i.loc[i_i['putting_item_into_bag_in_the_2nd_time'].isnull(), :]], axis=0).drop_duplicates()   
null.head(5)
# Out:
#    si_id  shelf_id  item_id  person_id           timestamp        date  \
# 16   012         0       12          2 2024-07-06 10:41:00  2024-07-06
# 17    06         0        6          2 2024-07-06 10:45:00  2024-07-06
# 19    19         1        9          3 2024-07-06 10:26:00  2024-07-06
# 34   715         7       15          5 2024-07-06 10:46:00  2024-07-06
# 35   714         7       14          5 2024-07-06 10:51:00  2024-07-06
#
#         time  holding_the_bag  picking_up_item  returning_item  \
# 16  10:41:00             True             True            True
# 17  10:45:00             True             True            True
# 19  10:26:00             True             True            True
# 34  10:46:00             True             True            True
# 35  10:51:00             True             True            True
#
#    putting_item_into_bag taking_item_out_of_bag  \
# 16                   NaN                   True
# 17                   NaN                    NaN
# 19                   NaN                   True
# 34                   NaN                  False
# 35                   NaN                   True
#
#    putting_item_into_bag_in_the_2nd_time  holding_the_item_(s)  \
# 16                                  True                  True
# 17                                   NaN                  True
# 19                                  True                  True
# 34                                  True                  True
# 35                                  True                  True
#
#     looking_at_item_(s)
# 16                 True
# 17                 True
# 19                 True
# 34                 True
# 35                 True

# %%
null[(null['putting_item_into_bag'].isnull()) & (null['putting_item_into_bag_in_the_2nd_time'].isnull()) &(null['returning_item']==False) ]
# Out:
# Empty DataFrame
# Columns: [si_id, shelf_id, item_id, person_id, timestamp, date, time, holding_the_bag, picking_up_item, returning_item, putting_item_into_bag, taking_item_out_of_bag, putting_item_into_bag_in_the_2nd_time, holding_the_item_(s), looking_at_item_(s)]
# Index: []

# %% [markdown]
# null[(null['putting_item_into_bag'].isnull()) & (null['putting_item_into_bag_in_the_2nd_time'].isnull()) &(null['returning_item']==False) ]
# 0 rows
# #### CONFIRM: 1 of the 2 put columns with null will always have a value when 'returning_item' == False indicating buy

# %%
i_i.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15394 entries, 0 to 15393
# Data columns (total 15 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   si_id                                  15394 non-null  object
#  1   shelf_id                               15394 non-null  int64
#  2   item_id                                15394 non-null  int64
#  3   person_id                              15394 non-null  int64
#  4   timestamp                              15394 non-null  datetime64[ns]
#  5   date                                   15394 non-null  object
#  6   time                                   15394 non-null  object
#  7   holding_the_bag                        15394 non-null  bool
#  8   picking_up_item                        15394 non-null  bool
#  9   returning_item                         15394 non-null  bool
#  10  putting_item_into_bag                  14056 non-null  object
#  11  taking_item_out_of_bag                 13452 non-null  object
#  12  putting_item_into_bag_in_the_2nd_time  12723 non-null  object
#  13  holding_the_item_(s)                   15394 non-null  bool
#  14  looking_at_item_(s)                    15394 non-null  bool
# dtypes: bool(5), datetime64[ns](1), int64(3), object(6)
# memory usage: 1.2+ MB

# %%
i_i[i_i.duplicated(subset=['si_id','date','time', 'person_id'])]
# each observation is of 1 customer - 1 product&shelf - @ 1 time-date stamp
# Out:
# Empty DataFrame
# Columns: [si_id, shelf_id, item_id, person_id, timestamp, date, time, holding_the_bag, picking_up_item, returning_item, putting_item_into_bag, taking_item_out_of_bag, putting_item_into_bag_in_the_2nd_time, holding_the_item_(s), looking_at_item_(s)]
# Index: []

# %% [markdown]
# logic of buy = Mặt hàng được xem là “được mua” khi mặt hàng đấy được bỏ vào giỏ hàng và không được lấy ra \
# “looking at item” → “picking up item” → “holding the item” → “put item into bag” (disregard put_item_into_the_bag_the_2nd_time == False/Nan)

# %% [markdown]
# ##### filtering i_i for buy == true (definite True condition <->  Nan = not statisfying condition)
# 1. Not returning items
# 2. Not taking items out of the bag\
#     Since taking_item_out_of_bag has Nan (representing missing data) -> filtering based on taking_item_out_of_bag == False
# 3. Since putting_item_into_bag and putting_item_into_bag_the_2nd_time has Nan (representing missing data) -> filtering based on whether the 2nd time value is True and if not true then the 1st value and both not returning and not taking must be false
#     (['putting_item_into_bag_in_the_2nd_time'] == True) # all putting_item_into_bag_in_the_2nd_time that is True takes precedent over putting_item_into_bag and taking_item_out_of_bag bc it indicates the lattermost action \
#     or \
#     (['putting_item_into_bag_in_the_2nd_time'] != True) & (['putting_item_into_bag'] == False)  # Include putting_item_into_bag_in_the_2nd_time NaN as "no action"
#
# 4. Review the distinct combinations of the 4 column returning_item	putting_item_into_bag	taking_item_out_of_bag	putting_item_into_bag_in_the_2nd_time	to determine buy after filtering == True case

# %%
# buy=i_i[i_i['returning_item']==False] # NO RETURN ACTION: 8698 out of 15394
# buy=buy[buy['taking_item_out_of_bag'] != True] # NO TAKING_OUT ACTION 5399 out of 8698 (630 taking_out na)
# # buy = buy[
# #     ((buy['putting_item_into_bag'] == True) | (buy['putting_item_into_bag'].isna())) &  # Include NaN as "no action"
# #     ((buy['putting_item_into_bag_in_the_2nd_time'] == True) | (buy['putting_item_into_bag_in_the_2nd_time'].isna()))  # Include NaN as "no action"
# # ]
# buy=buy[
#     (buy['putting_item_into_bag'] != False ) & (buy['putting_item_into_bag_in_the_2nd_time'] != False ) ] # NO 2 FALSE PUT ACTION 2045 out of 5399

# buy.drop_duplicates(subset=['putting_item_into_bag', 'taking_item_out_of_bag','putting_item_into_bag_in_the_2nd_time'])

# %% [markdown]
# #### DEFINED BUY LOGIC:

# %%
buy=i_i[(
  (i_i['returning_item']==False) &
  (i_i['taking_item_out_of_bag'] == False) & 
  (
    (
      (i_i['putting_item_into_bag_in_the_2nd_time'] == True) # all putting_item_into_bag_in_the_2nd_time that is True takes precedent over putting_item_into_bag and taking_item_out_of_bag bc it indicates the lattermost action 
    ) | 
    (
      (i_i['putting_item_into_bag_in_the_2nd_time'] != True) & # putting_item_into_bag_in_the_2nd_time =[False & Nan NaN as "no action"]
      (i_i['putting_item_into_bag'] ==True) & (i_i['taking_item_out_of_bag'] == False)
      ) 
  ) 
 )]
buy.drop_duplicates(subset=['returning_item','putting_item_into_bag', 'taking_item_out_of_bag','putting_item_into_bag_in_the_2nd_time'])
# Out:
#    si_id  shelf_id  item_id  person_id           timestamp        date  \
# 0    416         4       16          1 2024-07-06 10:00:00  2024-07-06
# 5     45         4        5          1 2024-07-06 10:12:00  2024-07-06
# 21    27         2        7          3 2024-07-06 10:31:00  2024-07-06
# 23    27         2        7          3 2024-07-06 10:37:00  2024-07-06
#
#         time  holding_the_bag  picking_up_item  returning_item  \
# 0   10:00:00             True             True           False
# 5   10:12:00             True             True           False
# 21  10:31:00             True             True           False
# 23  10:37:00             True             True           False
#
#    putting_item_into_bag taking_item_out_of_bag  \
# 0                  False                  False
# 5                   True                  False
# 21                  True                  False
# 23                  True                  False
#
#    putting_item_into_bag_in_the_2nd_time  holding_the_item_(s)  \
# 0                                   True                  True
# 5                                   True                  True
# 21                                   NaN                  True
# 23                                 False                  True
#
#     looking_at_item_(s)
# 0                  True
# 5                  True
# 21                 True
# 23                 True

# %% [markdown]
# **note**:
# all the rows with (i_i['putting_item_into_bag_in_the_2nd_time'] != True) & (i_i['putting_item_into_bag'] != False) have the i_i['taking_item_out_of_bag'] as False

# %%
i_i['is_buy'] = (
    (i_i['returning_item'] == False) &
    (i_i['taking_item_out_of_bag'] == False) & 
    (
        (i_i['putting_item_into_bag_in_the_2nd_time'] == True) | 
        (
            (i_i['putting_item_into_bag_in_the_2nd_time'] != True) & 
            (i_i['putting_item_into_bag'] ==True) & (i_i['taking_item_out_of_bag'] == False)
        )
    )
).astype(bool)

# %%
i_i['dow'] =pd.to_datetime(i_i['date']).dt.day_name() 
i_i
# Out:
#       si_id  shelf_id  item_id  person_id           timestamp        date  \
# 0       416         4       16          1 2024-07-06 10:00:00  2024-07-06
# 1        45         4        5          1 2024-07-06 10:02:00  2024-07-06
# 2        44         4        4          1 2024-07-06 10:05:00  2024-07-06
# 3        48         4        8          1 2024-07-06 10:06:00  2024-07-06
# 4        46         4        6          1 2024-07-06 10:08:00  2024-07-06
# ...     ...       ...      ...        ...                 ...         ...
# 15389    24         2        4       1500 2024-07-05 03:49:00  2024-07-05
# 15390    33         3        3       1500 2024-07-05 03:54:00  2024-07-05
# 15391   321         3       21       1500 2024-07-05 03:56:00  2024-07-05
# 15392   313         3       13       1500 2024-07-05 03:58:00  2024-07-05
# 15393    37         3        7       1500 2024-07-05 04:03:00  2024-07-05
#
#            time  holding_the_bag  picking_up_item  returning_item  \
# 0      10:00:00             True             True           False
# 1      10:02:00             True             True           False
# 2      10:05:00             True             True            True
# 3      10:06:00             True             True            True
# 4      10:08:00             True             True           False
# ...         ...              ...              ...             ...
# 15389  03:49:00            False             True           False
# 15390  03:54:00            False             True           False
# 15391  03:56:00            False             True           False
# 15392  03:58:00            False             True           False
# 15393  04:03:00            False             True           False
#
#       putting_item_into_bag taking_item_out_of_bag  \
# 0                     False                  False
# 1                      True                   True
# 2                      True                   True
# 3                     False                  False
# 4                     False                  False
# ...                     ...                    ...
# 15389                  True                   True
# 15390                  True                   True
# 15391                 False                   True
# 15392                 False                   True
# 15393                  True                   True
#
#       putting_item_into_bag_in_the_2nd_time  holding_the_item_(s)  \
# 0                                      True                  True
# 1                                      True                  True
# 2                                     False                  True
# 3                                     False                  True
# 4                                      True                  True
# ...                                     ...                   ...
# 15389                                  True                  True
# 15390                                  True                  True
# 15391                                 False                  True
# 15392                                  True                  True
# 15393                                 False                  True
#
#        looking_at_item_(s)  is_buy       dow
# 0                     True    True  Saturday
# 1                     True   False  Saturday
# 2                     True   False  Saturday
# 3                     True   False  Saturday
# 4                     True    True  Saturday
# ...                    ...     ...       ...
# 15389                 True   False    Friday
# 15390                 True   False    Friday
# 15391                 True   False    Friday
# 15392                 True   False    Friday
# 15393                 True   False    Friday
#
# [15394 rows x 17 columns]

# %% [markdown]
# ### 2.2 Create demographic df
# - create 'age_group' col

# %%
demo = df_cust[['person_id','si_id','timestamp', 'age','height','weight','married_status', 'moving_speed_(m/s)']]

# %%
bins = [18, 31, 61, demo['age'].max() + 1]
labels = [1, 2, 3]
demo['age_group'] = pd.cut(demo.age, bins=bins, labels=labels, right=False)
# Out:
# /tmp/ipykernel_5304/552342526.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   demo['age_group'] = pd.cut(demo.age, bins=bins, labels=labels, right=False)

# %%
demo.head()
# Out:
#    person_id si_id           timestamp  age  height  weight married_status  \
# 0          1   416 2024-07-06 10:00:00   52     162      41        Married
# 1          1    45 2024-07-06 10:02:00   52     162      41        Married
# 2          1    44 2024-07-06 10:05:00   52     162      41        Married
# 3          1    48 2024-07-06 10:06:00   52     162      41        Married
# 4          1    46 2024-07-06 10:08:00   52     162      41        Married
#
#    moving_speed_(m/s) age_group
# 0                0.19         2
# 1                0.49         2
# 2                0.36         2
# 3                0.64         2
# 4                0.13         2

# %% [markdown]
# ## 3. df_shelf
# - 8 rows
# - 9 cols
#
# TODO:
# - plot map for q11
# - rename column to camel case

# %%
df_shelf.head()
# Out:
#    Shelf ID       Description  Location_x (center)  Location_y (center)  \
# 0         0     Quầy bánh kẹo                 1100                  550
# 1         1  Quầy hoá mỹ phẩm                  350                  500
# 2         2          Quầy sữa                  600                  400
# 3         3    Quầy thực phẩm                 1450                  400
# 4         4       Quầy gia vị                 1100                  150
#
#    Width  Height  Length  Number of items      Shape
# 0    300     180     300               13  Quầy tròn
# 1    100     180     400               18    Kệ hàng
# 2    100     180     600                9    Kệ hàng
# 3    100     180     600               25    Kệ hàng
# 4    500     180     100               19    Kệ hàng

# %%
print(df_shelf.describe(), df_shelf.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Shelf ID             8 non-null      int64
#  1   Description          8 non-null      object
#  2   Location_x (center)  8 non-null      int64
#  3   Location_y (center)  8 non-null      int64
#  4   Width                8 non-null      int64
#  5   Height               8 non-null      int64
#  6   Length               8 non-null      int64
#  7   Number of items      8 non-null      int64
#  8   Shape                8 non-null      object
# dtypes: int64(7), object(2)
# memory usage: 704.0+ bytes
#        Shelf ID  Location_x (center)  Location_y (center)       Width  Height  \
# count   8.00000             8.000000             8.000000    8.000000     8.0
# mean    3.50000           768.750000           537.500000  325.000000   180.0
# std     2.44949           496.370757           279.987245  271.240536     0.0
# min     0.00000            50.000000           150.000000  100.000000   180.0
# 25%     1.75000           350.000000           400.000000  100.000000   180.0
# 50%     3.50000           850.000000           450.000000  200.000000   180.0
# 75%     5.25000          1112.500000           650.000000  550.000000   180.0
# max     7.00000          1450.000000           950.000000  700.000000   180.0
#
#            Length  Number of items
# count    8.000000           8.0000
# mean   350.000000          16.5000
# std    232.992949           4.6291
# min    100.000000           9.0000
# 25%    100.000000          15.2500
# 50%    350.000000          16.0000
# 75%    600.000000          18.2500
# max    600.000000          25.0000   None

# %%
df_shelf_col = df_shelf.columns.to_list()
df_shelf_col_new={col:re.sub(' ','_', col.strip()).lower() for col in df_shelf_col}
df_shelf.rename(columns=df_shelf_col_new,inplace=True)

# %%
# df_shelf['location_x_(center)'].min()-df_shelf[df_shelf['location_x_(center)']==df_shelf['location_x_(center)'].min()]['width']/2, # padding for center
# df_shelf['location_x_(center)'].max() +df_shelf[df_shelf['location_x_(center)']==df_shelf['location_x_(center)'].max()]['width']/2
# df_shelf['location_y_(center)'].min() -df_shelf[df_shelf['location_y_(center)']==df_shelf['location_y_(center)'].min()]['length']/2, # padding for center ,
df_shelf['location_y_(center)'].max()+df_shelf[df_shelf['location_y_(center)']==df_shelf['location_y_(center)'].max()]['length']/2
# Out:
# 5    1000.0
# 7    1000.0
# Name: length, dtype: float64

# %%
import matplotlib.patches as patches
fig, ax = plt.subplots()

for index, row in df_shelf.iterrows():
    x = row['location_x_(center)']
    y = row['location_y_(center)']
    width = row['width']
    height = row['height']
    if row['shape'] == 'Kệ hàng':  
        rect = patches.Rectangle((x - width/2, y - height/2), width, height, linewidth=1, edgecolor='blue', facecolor='none')
        ax.add_patch(rect)
    elif row['shape'] == 'Quầy tròn':  
        circle = patches.Circle((x, y), width/2, linewidth=1, edgecolor='red', facecolor='none')
        ax.add_patch(circle)
    ax.text(x, y, str(row['shelf_id']) + ' ' + row['description'], fontsize=8, ha='center')

ax.set_xlim(0,1500)
ax.set_ylim(0,1000)

ax.set_xlabel('x position')
ax.set_ylabel('y position')
ax.set_title('Layout')

plt.gca().set_aspect('equal', adjustable='box')
plt.show()

# %%
df_shelf.head()
# Out:
#    shelf_id       description  location_x_(center)  location_y_(center)  \
# 0         0     Quầy bánh kẹo                 1100                  550
# 1         1  Quầy hoá mỹ phẩm                  350                  500
# 2         2          Quầy sữa                  600                  400
# 3         3    Quầy thực phẩm                 1450                  400
# 4         4       Quầy gia vị                 1100                  150
#
#    width  height  length  number_of_items      shape
# 0    300     180     300               13  Quầy tròn
# 1    100     180     400               18    Kệ hàng
# 2    100     180     600                9    Kệ hàng
# 3    100     180     600               25    Kệ hàng
# 4    500     180     100               19    Kệ hàng

# %% [markdown]
# # 4. ANSWERS:

# %% [markdown]
# ## Q1
# Thống kê ***5 mặt hàng*** có **tổng thời gian nhìn và cầm xem lâu nhất**?

# %%
ans1 = df_cust.groupby('si_id')[['looking_at_item_(s)', 'holding_the_item_(s)']].sum().reset_index()
ans1['total_time']=ans1['looking_at_item_(s)']+ans1['holding_the_item_(s)']
ans1=pd.merge(right=ans1,left=df_item, how='right', on='si_id')
ans1[['shelf_id'	,'item_id',	'name','total_time']].sort_values(by='total_time', ascending=False).head(5)
# Out:
#      shelf_id  item_id                  name  total_time
# 130         7        6  Sữa chua uống Yakult       22896
# 131         7        7   Sữa chua uống Probi       22896
# 39          2        8           Sữa ông thọ       13939
# 9           0        6         Bim bim Oishi       13866
# 10          0        7  Snack khoai tây Lays       13362

# %% [markdown]
# ## Q2
# Thống kê ***5 mặt hàng*** thường **được cầm lên rồi trả lại nhiều nhất**?

# %%
# picking_up_item & returning_item have no nulls 
ans2=df_cust[['si_id','picking_up_item','returning_item']]
ans2=ans2[(ans2['picking_up_item']==True) & (ans2['returning_item']==True)].groupby('si_id').count().sort_values(by='picking_up_item',ascending=False).reset_index()
ans2=pd.merge(right=ans2, left=df_item[['name', 'si_id']], how='right', on='si_id' )
ans2=ans2.drop(columns=['picking_up_item'])
ans2.head(5)
# Out:
#                             name si_id  returning_item
# 0  4 hộp sữa lúa mạch Milo 180ml    22             134
# 1           Snack khoai tây Lays    07             127
# 2                   Mý ý SG Food   712             117
# 3                Nước lẩu Barona   714             116
# 4               Sữa chua Vinamik    72             114

# %% [markdown]
# ## Q8
# Top 3 quầy hàng có thời lượng trung bình quan tâm đến sản phẩm, trên số lượt tương tác, là lâu nhất (quan tâm tương ứng với việc **nhìn và cầm xem**)?

# %%
si_total_ii_time = df_cust.groupby(['shelf_id'])[['holding_the_item_(s)','looking_at_item_(s)']].sum().reset_index()
si_total_ii_count= i_i.groupby(['shelf_id'])[['holding_the_item_(s)','looking_at_item_(s)']].sum().reset_index()
ans8=pd.merge(left=si_total_ii_time, right=si_total_ii_count, how='left', on='shelf_id')
ans8['avg_ii'] = ans8['holding_the_item_(s)_x']/ans8['holding_the_item_(s)_y'] + ans8['looking_at_item_(s)_x']/ans8['looking_at_item_(s)_y']
ans8=ans8[['avg_ii', 'shelf_id']].sort_values(by='avg_ii', ascending=False)
ans8=pd.merge(left=ans8, right=df_shelf, on='shelf_id', how='left' )
ans8[['shelf_id','description', 'avg_ii']].sort_values(by='avg_ii', ascending=False).head(3)
# Out:
#    shelf_id     description     avg_ii
# 0         5   Quầy gia dụng  62.260184
# 1         7  Quầy đông lạnh  61.009985
# 2         3  Quầy thực phẩm  59.845622

# %% [markdown]
# ## Q10
# Người dùng có thói quen di chuyển giữa 2 quầy hàng nào nhiều nhất?

# %%
path=i_i[['person_id', 'shelf_id','date']].drop_duplicates().reset_index(drop=True)

# %%
ans = path.groupby(['person_id', 'date'])['shelf_id'].apply(list).reset_index()
def create_pairwise_path(shelf_ids):
    pairs = []
    if len(shelf_ids) ==1:
        pairs.append((shelf_ids[0],None))
    else:
        for i in range(len(shelf_ids) - 1):
            pairs.append((shelf_ids[i],shelf_ids[i + 1]))
         
    return pairs

ans['path'] = ans['shelf_id'].apply(create_pairwise_path)
ans.drop(columns='shelf_id', inplace=True)

# %%
all_paths = [path for sublist in ans['path'] for path in sublist]
from collections import Counter
path_counts = Counter(all_paths)
most_common_path, most_common_count = path_counts.most_common(1)[0]
ans10=(most_common_path, most_common_count)
ans10
# Out:
# ((7, 0), 97)

# %% [markdown]
# ## Q5
# Trong 3 nhóm tuổi sau: Thiếu niên (18 - 30), Trung niên (31 - 60), Cao tuổi: (> 60), nhóm tuổi nào có **số người đi siêu thị nhiều nhất?**

# %%
shopper_freq=df_cust[['person_id','age', 'date']]
bins = [18, 31, 61, shopper_freq['age'].max() + 1]
labels = [1, 2, 3]

shopper_freq['age_group'] = pd.cut(shopper_freq.age, bins=bins, labels=labels, right=False)
shopper_freq=shopper_freq.drop(columns=['age'])
ans5=shopper_freq.groupby('age_group').count().reset_index(drop=True)
ans5
# Out:
# /tmp/ipykernel_5304/2186068833.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shopper_freq['age_group'] = pd.cut(shopper_freq.age, bins=bins, labels=labels, right=False)
# /tmp/ipykernel_5304/2186068833.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   ans5=shopper_freq.groupby('age_group').count().reset_index(drop=True)
#    person_id  date
# 0       3574  3574
# 1       7617  7617
# 2       4203  4203

# %% [markdown]
# ## Q3
# Các nhóm khách hàng theo độ tuổi (Thiếu niên: 18 - 30; Trung niên: 31 - 60; Cao tuổi: > 60) **mua** mặt hàng nào nhiều nhất?

# %%
shopper_buy=pd.merge(left=demo[['age_group', 'si_id', 'person_id','timestamp']], right=i_i[['si_id', 'person_id', 'timestamp','is_buy']], how='inner', on=['si_id', 'person_id', 'timestamp'])
shopper_buy=pd.merge(left=shopper_buy.groupby(['age_group','si_id'])['is_buy'].sum().reset_index(), right=df_item, how='right', on='si_id')
shopper_buy=shopper_buy[['si_id','age_group', 'is_buy','name']].sort_values(by='is_buy',ascending=False).reset_index(drop=True)
ans3=shopper_buy.drop_duplicates(subset=['age_group'],keep='first').sort_values(by='age_group',ascending=True)
ans3
# Out:
# /tmp/ipykernel_5304/707363991.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   shopper_buy=pd.merge(left=shopper_buy.groupby(['age_group','si_id'])['is_buy'].sum().reset_index(), right=df_item, how='right', on='si_id')
#    si_id age_group  is_buy                name
# 10    04         1      41  Bánh trứng Custard
# 0     70         2      86      Kem tràng tiền
# 4     04         3      50  Bánh trứng Custard

# %% [markdown]
# ## Q6
# Top 5 các mặt hàng giảm giá được người dùng **mua** nhiều nhất?

# %%
ans6=pd.merge(left=i_i.groupby('si_id')['is_buy'].sum().sort_values(ascending=False), right=df_item, how='left',on='si_id').sort_values(by='is_buy', ascending=False)
ans6[ans6['discount'] > 0].sort_values(by='is_buy',ascending=False)[['name','si_id', 'is_buy','discount']].set_index('si_id').head(5)
# Out:
#                      name  is_buy  discount
# si_id
# 04     Bánh trứng Custard     159        10
# 70         Kem tràng tiền     154         5
# 27           Sữa bột Milo     154        15
# 11         Dầu gội Romano      95        25
# 111        Khăn mặt Shine      90        20

# %% [markdown]
# ## Q7
# Top 5 các mặt hàng được chạy quảng cáo được người dùng **mua** nhiều nhất?

# %%
ans7=pd.merge(left=i_i.groupby('si_id')['is_buy'].sum().sort_values(ascending=False), right=df_item, how='left',on='si_id').sort_values(by='is_buy', ascending=False)
ans7[ans7['marketing_strategy'] == True].sort_values(by='is_buy',ascending=False)[['name','si_id', 'is_buy','marketing_strategy']].set_index('si_id').head(5)
# Out:
#                      name  is_buy  marketing_strategy
# si_id
# 04     Bánh trứng Custard     159                True
# 70         Kem tràng tiền     154                True
# 27           Sữa bột Milo     154                True
# 111        Khăn mặt Shine      90                True
# 110        Khăn tắm Shine      87                True

# %% [markdown]
# ## Q4
# Ngày nào trong tuần có doanh thu cao nhất?

# %%
ans4=pd.merge(left=i_i[['dow', 'si_id', 'is_buy']], right=df_item[['si_id', 'name', 'price_vnd']], how='right', on='si_id')
ans4[ans4['is_buy']==True].groupby('dow')['price_vnd'].sum().sort_values(ascending=False).head(1)
# Out:
# dow
# Saturday    174194600
# Name: price_vnd, dtype: int64

# %% [markdown]
# ## Q9
# Top 3 quầy hàng có số sản phẩm được **mua** nhiều nhất?

# %%
ans9=pd.merge(left=i_i[['shelf_id','is_buy']], right=df_shelf[['shelf_id', 'description', 'number_of_items']], how='left', on='shelf_id')
ans9[ans9['is_buy']==True].groupby(['shelf_id', 'description', 'number_of_items']).count().reset_index().sort_values(by='is_buy',ascending=False).head(3)
# Out:
#    shelf_id       description  number_of_items  is_buy
# 1         1  Quầy hoá mỹ phẩm               18     840
# 7         7    Quầy đông lạnh               16     675
# 0         0     Quầy bánh kẹo               13     586

# %% [markdown]
# # 5. Combined df for Q11 & Q12

# %%
item_shelf=pd.merge(left=df_item, right=df_shelf, how='left', on='shelf_id')

# %%
df = pd.merge(left=df_cust, right=item_shelf, how='left', on=['shelf_id','item_id','si_id'])
df['buy'] = i_i['is_buy']

# %%
df_col = df.columns.to_list()
print(df_col)
# Out:
# ['shelf_id', 'person_id', 'timestamp', 'age', 'gender', 'height_x', 'weight', 'married_status', 'moving_speed_(m/s)', 'item_id', 'looking_at_item_(s)', 'holding_the_item_(s)', 'holding_the_bag', 'picking_up_item', 'returning_item', 'putting_item_into_bag', 'taking_item_out_of_bag', 'putting_item_into_bag_in_the_2nd_time', 'si_id', 'date', 'time', 'name', 'origin', 'location', 'weight_(g)', 'price_vnd', 'nsx', 'hsd', 'marketing_strategy', 'discount', 'rate', 'description', 'location_x_(center)', 'location_y_(center)', 'width', 'height_y', 'length', 'number_of_items', 'shape', 'buy']

# %% [markdown]
# ['shelf_id', 'person_id', 'timestamp', 'age', 'gender', 'height_x', 'weight', 'married_status', 'moving_speed_(m/s)', 'item_id', 'looking_at_item_(s)', 'holding_the_item_(s)', 'holding_the_bag', 'picking_up_item', 'returning_item', 'putting_item_into_bag', 'taking_item_out_of_bag', 'putting_item_into_bag_in_the_2nd_time', 'si_id', 'date', 'time', 'name', 'origin', 'location', 'weight_(g)', 'price_vnd', 'nsx', 'hsd', 'marketing_strategy', 'discount', 'rate', 'description', 'location_x_(center)', 'location_y_(center)', 'width', 'height_y', 'length', 'number_of_items', 'shape', 'buy']

# %%
df_col_new = {col: re.sub(r'[()]', '', col.strip()).lower() for col in df_col}
df.rename(columns=df_col_new, inplace=True)
df.rename(columns={'holding_the_item_s':'holding_item_duration','looking_at_item_s':'looking_at_item_duration', 'height_x':'cust_height','height_y':'shelf_height'},inplace=True)

# %%
df=df.dropna(subset=['putting_item_into_bag','taking_item_out_of_bag',	'putting_item_into_bag_in_the_2nd_time'])
print(df.columns.to_list())
# Out:
# ['shelf_id', 'person_id', 'timestamp', 'age', 'gender', 'cust_height', 'weight', 'married_status', 'moving_speed_m/s', 'item_id', 'looking_at_item_duration', 'holding_item_duration', 'holding_the_bag', 'picking_up_item', 'returning_item', 'putting_item_into_bag', 'taking_item_out_of_bag', 'putting_item_into_bag_in_the_2nd_time', 'si_id', 'date', 'time', 'name', 'origin', 'location', 'weight_g', 'price_vnd', 'nsx', 'hsd', 'marketing_strategy', 'discount', 'rate', 'description', 'location_x_center', 'location_y_center', 'width', 'shelf_height', 'length', 'number_of_items', 'shape', 'buy']

# %% [markdown]
# ['shelf_id', 'person_id', 'timestamp', \
# 'age', 'gender', 'cust_height', 'weight', 'married_status', 'moving_speed_m/s', 'item_id', 'looking_at_item_duratiion', 'holding_item_duration', \
# 'holding_the_bag', 'picking_up_item', 'returning_item', 'putting_item_into_bag', 'taking_item_out_of_bag', 'putting_item_into_bag_in_the_2nd_time', \
# 'si_id', 'date', 'time', 'name', 'origin', 'location', 'weight_g', 'price_vnd', 'nsx', 'hsd', 'marketing_strategy', 'discount', 'rate', \
# 'description', 'location_x_center', 'location_y_center', 'width', 'shelf_height', 'length', 'number_of_items', 'shape', 'buy']

# %%
df.isnull().sum()[df.isnull().sum()>0]
# Out:
# weight_g    1681
# nsx         1280
# hsd         1280
# dtype: int64

# %%
grouped_means = df.groupby('description')['weight_g'].transform('mean')
df['weight_g'] = df['weight_g'].fillna(grouped_means)
df=df.drop(columns=['nsx','hsd'])

# %% [markdown]
# #### onehot encoding:

# %%
onehot=df[df.dtypes[df.dtypes=='object'].index.to_list()].columns.to_list()

# %%
df=df.drop(columns=['si_id', 'date', 'time', 'name']) # drop si_id, date, time because not needed 
onehot=df[df.dtypes[df.dtypes=='object'].index.to_list()].columns.to_list()
onehot
# Out:
# ['gender',
#  'married_status',
#  'putting_item_into_bag',
#  'taking_item_out_of_bag',
#  'putting_item_into_bag_in_the_2nd_time',
#  'origin',
#  'location',
#  'description',
#  'shape']

# %%
df = pd.get_dummies(df, columns=onehot, drop_first=True)
df
# Out:
#        shelf_id  person_id           timestamp  age  cust_height  weight  \
# 0             4          1 2024-07-06 10:00:00   52          162      41
# 1             4          1 2024-07-06 10:02:00   52          162      41
# 2             4          1 2024-07-06 10:05:00   52          162      41
# 3             4          1 2024-07-06 10:06:00   52          162      41
# 4             4          1 2024-07-06 10:08:00   52          162      41
# ...         ...        ...                 ...  ...          ...     ...
# 15389         2       1500 2024-07-05 03:49:00   52          154      44
# 15390         3       1500 2024-07-05 03:54:00   52          154      44
# 15391         3       1500 2024-07-05 03:56:00   52          154      44
# 15392         3       1500 2024-07-05 03:58:00   52          154      44
# 15393         3       1500 2024-07-05 04:03:00   52          154      44
#
#        moving_speed_m/s  item_id  looking_at_item_duration  \
# 0                  0.19       16                        27
# 1                  0.49        5                        22
# 2                  0.36        4                        25
# 3                  0.64        8                        21
# 4                  0.13        6                        27
# ...                 ...      ...                       ...
# 15389              0.52        4                        32
# 15390              0.85        3                        30
# 15391              0.76       21                        54
# 15392              1.41       13                        16
# 15393              0.96        7                        17
#
#        holding_item_duration  ...  location_Thấp  location_Trung bình  \
# 0                         36  ...          False                 True
# 1                         17  ...          False                False
# 2                         39  ...          False                False
# 3                         35  ...           True                False
# 4                         16  ...          False                False
# ...                      ...  ...            ...                  ...
# 15389                     35  ...           True                False
# 15390                     28  ...          False                 True
# 15391                     56  ...          False                 True
# 15392                     25  ...          False                False
# 15393                     37  ...          False                 True
#
#        description_Quầy gia dụng  description_Quầy gia vị  \
# 0                          False                     True
# 1                          False                     True
# 2                          False                     True
# 3                          False                     True
# 4                          False                     True
# ...                          ...                      ...
# 15389                      False                    False
# 15390                      False                    False
# 15391                      False                    False
# 15392                      False                    False
# 15393                      False                    False
#
#        description_Quầy hoá mỹ phẩm  description_Quầy sách và đồ chơi  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
# ...                             ...                               ...
# 15389                         False                             False
# 15390                         False                             False
# 15391                         False                             False
# 15392                         False                             False
# 15393                         False                             False
#
#        description_Quầy sữa  description_Quầy thực phẩm  \
# 0                     False                       False
# 1                     False                       False
# 2                     False                       False
# 3                     False                       False
# 4                     False                       False
# ...                     ...                         ...
# 15389                  True                       False
# 15390                 False                        True
# 15391                 False                        True
# 15392                 False                        True
# 15393                 False                        True
#
#        description_Quầy đông lạnh  shape_Quầy tròn
# 0                           False            False
# 1                           False            False
# 2                           False            False
# 3                           False            False
# 4                           False            False
# ...                           ...              ...
# 15389                       False            False
# 15390                       False            False
# 15391                       False            False
# 15392                       False            False
# 15393                       False            False
#
# [10308 rows x 50 columns]

# %%
print(df.shape, df.info())
df.buy.value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10308 entries, 0 to 15393
# Data columns (total 50 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   shelf_id                                    10308 non-null  int64
#  1   person_id                                   10308 non-null  int64
#  2   timestamp                                   10308 non-null  datetime64[ns]
#  3   age                                         10308 non-null  int64
#  4   cust_height                                 10308 non-null  int64
#  5   weight                                      10308 non-null  int64
#  6   moving_speed_m/s                            10308 non-null  float64
#  7   item_id                                     10308 non-null  int64
#  8   looking_at_item_duration                    10308 non-null  int64
#  9   holding_item_duration                       10308 non-null  int64
#  10  holding_the_bag                             10308 non-null  bool
#  11  picking_up_item                             10308 non-null  bool
#  12  returning_item                              10308 non-null  bool
#  13  weight_g                                    10308 non-null  float64
#  14  price_vnd                                   10308 non-null  int64
#  15  marketing_strategy                          10308 non-null  bool
#  16  discount                                    10308 non-null  int64
#  17  rate                                        10308 non-null  int64
#  18  location_x_center                           10308 non-null  int64
#  19  location_y_center                           10308 non-null  int64
#  20  width                                       10308 non-null  int64
#  21  shelf_height                                10308 non-null  int64
#  22  length                                      10308 non-null  int64
#  23  number_of_items                             10308 non-null  int64
#  24  buy                                         10308 non-null  bool
#  25  gender_Male                                 10308 non-null  bool
#  26  married_status_Single                       10308 non-null  bool
#  27  putting_item_into_bag_True                  10308 non-null  bool
#  28  taking_item_out_of_bag_True                 10308 non-null  bool
#  29  putting_item_into_bag_in_the_2nd_time_True  10308 non-null  bool
#  30  origin_Hàn Quốc                             10308 non-null  bool
#  31  origin_Malaysia                             10308 non-null  bool
#  32  origin_New Zealand                          10308 non-null  bool
#  33  origin_Nhật Bản                             10308 non-null  bool
#  34  origin_Thailand                             10308 non-null  bool
#  35  origin_Thái Lan                             10308 non-null  bool
#  36  origin_Trung Quốc                           10308 non-null  bool
#  37  origin_Vietnam                              10308 non-null  bool
#  38  origin_Úc                                   10308 non-null  bool
#  39  origin_Ý                                    10308 non-null  bool
#  40  location_Thấp                               10308 non-null  bool
#  41  location_Trung bình                         10308 non-null  bool
#  42  description_Quầy gia dụng                   10308 non-null  bool
#  43  description_Quầy gia vị                     10308 non-null  bool
#  44  description_Quầy hoá mỹ phẩm                10308 non-null  bool
#  45  description_Quầy sách và đồ chơi            10308 non-null  bool
#  46  description_Quầy sữa                        10308 non-null  bool
#  47  description_Quầy thực phẩm                  10308 non-null  bool
#  48  description_Quầy đông lạnh                  10308 non-null  bool
#  49  shape_Quầy tròn                             10308 non-null  bool
# dtypes: bool(30), datetime64[ns](1), float64(2), int64(17)
# memory usage: 1.9 MB
# (10308, 50) None
# buy
# False    6986
# True     3322
# Name: count, dtype: int64

# %%
y=df['buy']
X=df.drop(columns=['buy'])

# %% [markdown]
# ## Q11
# Có những mặt hàng nào cần được sắp xếp lại trong cửa hàng không?

# %% [markdown]
# - Using Kmeans to do groupping of low/high interaction and low/high purchase behaviour
# - columns needed:
# - - columns of df_item: item_id, price_vnd, location, rate
# - - columns of cust: age, cust_height, weight, married_status, moving_speed_m/s, looking_at_item_duration, holding_item_duration, picking_up_item, returning_item, putting_item_into_bag, taking_item_out_of_bag, putting_item_into_bag_the_2nd_time
# - - columns of df_shelf: location_x_center, location_y_center, width, shelf_height, length, number_of_items, shape

# %% [markdown]
# ## Q12.
# Phân tích hiệu quả của các chiến dịch quảng cáo, sale đối với các mặt hàng. (Phần trình bày của thí sinh không quá 500 từ)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns


X_12 = X.drop(columns=['person_id','shelf_id', 'item_id', 'timestamp', 'putting_item_into_bag_True', 'taking_item_out_of_bag_True', 'putting_item_into_bag_in_the_2nd_time_True','returning_item' ])

X_train, X_test, y_train, y_test = train_test_split(X_12, y, test_size=0.3, random_state=1)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# #### a. LogReg model

# %%
logreg = LogisticRegression()
logreg.fit(X_train_scaled, y_train)
y_pred = logreg.predict(X_test_scaled)
print(classification_report(y_test, y_pred))
coefficients = pd.DataFrame({'Feature': X_train.columns, 'Coefficient': logreg.coef_[0]})
coefficients = coefficients.sort_values(by='Coefficient', ascending=False).head(15)
print(coefficients)
# Out:
#               precision    recall  f1-score   support
#
#        False       0.77      0.92      0.84      2110
#         True       0.71      0.39      0.50       983
#
#     accuracy                           0.75      3093
#    macro avg       0.74      0.66      0.67      3093
# weighted avg       0.75      0.75      0.73      3093
#
#                          Feature  Coefficient
# 11                      discount     0.561731
# 10            marketing_strategy     0.481352
# 28                origin_Vietnam     0.296753
# 24               origin_Nhật Bản     0.183862
# 37          description_Quầy sữa     0.156446
# 26               origin_Thái Lan     0.156109
# 39    description_Quầy đông lạnh     0.114888
# 19                   gender_Male     0.087970
# 27             origin_Trung Quốc     0.078760
# 25               origin_Thailand     0.070043
# 17                        length     0.056841
# 35  description_Quầy hoá mỹ phẩm     0.054720
# 21               origin_Hàn Quốc     0.051624
# 30                      origin_Ý     0.024683
# 14             location_y_center     0.016522

# %%
X_train, X_test, y_train, y_test = train_test_split(X_12, y, test_size=0.3, random_state=1)
print(y_train.shape, y_test.shape)
print(X_train.shape, X_test.shape)
# Out:
# (7215,) (3093,)
# (7215, 41) (3093, 41)

# %% [markdown]
# #### b. RFC model

# %%
rfc = RandomForestClassifier(n_estimators=100)
rfc.fit(X_train, y_train)

y_pred = rfc.predict(X_test)

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No Buy', 'Buy'], yticklabels=['No Buy', 'Buy'])
plt.ylabel('actual')
plt.xlabel('pred')
plt.title('Confusion matrix for test set')
plt.show()
y_train_pred = rfc.predict(X_train)
cm_train = confusion_matrix(y_train, y_train_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm_train, annot=True, fmt='d', cmap='Blues', xticklabels=['No Buy', 'Buy'], yticklabels=['No Buy', 'Buy'])
plt.ylabel('actual')
plt.xlabel('pred')
plt.title('Confusion matrix for train set')
plt.show()

# %%
print(classification_report(y_test, y_pred, target_names=['No Buy', 'Buy']), f'Accuracy: ')
print(classification_report(y_train, y_train_pred, target_names=['No Buy', 'Buy']))
# Out:
#               precision    recall  f1-score   support
#
#       No Buy       0.78      0.90      0.83      2110
#          Buy       0.68      0.46      0.55       983
#
#     accuracy                           0.76      3093
#    macro avg       0.73      0.68      0.69      3093
# weighted avg       0.75      0.76      0.74      3093
#  Accuracy:
#               precision    recall  f1-score   support
#
#       No Buy       1.00      1.00      1.00      4876
#          Buy       1.00      1.00      1.00      2339
#
#     accuracy                           1.00      7215
#    macro avg       1.00      1.00      1.00      7215
# weighted avg       1.00      1.00      1.00      7215

# %% [markdown]
# *note*: signs of overfitting

# %%
ft_importance = rfc.feature_importances_
std = np.std([tree.feature_importances_ for tree in rfc.estimators_], axis=0)
feature_names = [f"{X_12.columns[i]}" for i in range(X_12.shape[1])]
forest_importances = pd.Series(ft_importance, index=feature_names).sort_values(ascending=False)

fig, ax = plt.subplots(figsize=(20,10))
forest_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()
print(forest_importances.head(15))
# Out:
# moving_speed_m/s            0.119074
# looking_at_item_duration    0.106544
# holding_item_duration       0.106444
# age                         0.106047
# weight                      0.102466
# cust_height                 0.096851
# discount                    0.070704
# marketing_strategy          0.058369
# price_vnd                   0.053812
# weight_g                    0.039523
# married_status_Single       0.018722
# rate                        0.016274
# gender_Male                 0.012663
# holding_the_bag             0.010538
# number_of_items             0.008716
# dtype: float64

# %%
from sklearn.inspection import permutation_importance
perm_result = permutation_importance(
    rfc, X_test, y_test, n_repeats=10, random_state=42, n_jobs=2
)
sorted_importances_idx = (-perm_result.importances_mean).argsort()
perm_importances = pd.DataFrame(
    
    perm_result.importances[sorted_importances_idx].T,
    columns=X_12.columns[sorted_importances_idx],
)
ax = perm_importances.plot.box(vert=True, whis=10, figsize=(20,10))
ax.set_title("Permutation importances on test set")
ax.axhline(y=0, color="k", linestyle="--")
ax.set_ylabel("Decrease in accuracy score")
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.figure.tight_layout()

# %%
perm_train_result = permutation_importance(
    rfc, X_train, y_train, n_repeats=10, random_state=42, n_jobs=2
)
sorted_importances_idx_train = (-perm_train_result.importances_mean).argsort()
perm_train_importances = pd.DataFrame(
    perm_train_result.importances[sorted_importances_idx_train].T,
    columns=X_12.columns[sorted_importances_idx_train],
)
ax = perm_train_importances.plot.box(vert=True, whis=10, figsize=(20,10))
ax.set_title("Permutation importances on train set")
ax.axhline(y=0, color="k", linestyle="--")
ax.set_ylabel("Decrease in accuracy score")
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.figure.tight_layout()

# %%
print(perm_importances.T.mean(axis=1).head(15))
# Out:
# marketing_strategy            0.058164
# discount                      0.056127
# origin_Thái Lan               0.002522
# looking_at_item_duration      0.001940
# price_vnd                     0.001908
# number_of_items               0.001714
# origin_Úc                     0.000905
# description_Quầy đông lạnh    0.000323
# origin_Nhật Bản               0.000129
# origin_Malaysia               0.000065
# origin_Ý                      0.000000
# picking_up_item               0.000000
# shelf_height                  0.000000
# origin_New Zealand           -0.000032
# origin_Thailand              -0.000032
# dtype: float64

# %%
print(perm_train_importances.T.mean(axis=1).head(15))
# Out:
# price_vnd                   0.088468
# moving_speed_m/s            0.075066
# discount                    0.075024
# holding_item_duration       0.068732
# cust_height                 0.066486
# age                         0.064754
# looking_at_item_duration    0.063881
# weight                      0.063839
# weight_g                    0.060832
# marketing_strategy          0.060790
# married_status_Single       0.026667
# rate                        0.015038
# gender_Male                 0.010229
# holding_the_bag             0.007415
# location_Thấp               0.006819
# dtype: float64

# %% [markdown]
# ***Methodology***:
#
# I used two machine learning models - logistic regression and random forest classifier - to figure out how discounts and marketing strategies affect customer buying behavior. I prepared the dataset, performed basic data transformation (dropped null values as it is an invalid observation, one hot encoded features, drop unique identifier and action-definition features), split it into training and test sets with, and applied both models to understand what features matter most when predicting if someone will make a purchase.
# - For the logistic regression, I standardized the features and looked at the coefficients to see how each variable influenced the probability of a purchase.
# - For the random forest classifier, I started by using its built-in feature importance method. However, it is noted that this method might be biased towards features with lots of unique values, so I also used permutation importance on both test and training sets to further validate the findings.
# ***Findings***:
#
# - Logistic regression model:
# - - Discount and marketing strategy has the highest positive coefficients (0.561731 and 0.481352), indicating strong positive link to purchasing behavior.
#
# - Random forest classifier’s feature importance method:
# - - Discount and marketing strategy ranked 7th and 8th in importance.
# - - This might be skewed because of bias towards features like moving speed and how long customers look at items.
#
# - The permutation importance method on the test set:
# - - Marketing strategy (0.063466) and discount (0.057743) is in the top two spots.
# - - This matched up with what I saw in the logistic regression’s coefficient result.
#
# **Models’ performance**:
# - Both were decent with no tuning, accuracy 75%.
# - The random forest model showed signs it might be overfitting, as the results were quite different between the training and test sets with the test set having poor recall for Buy class.
#
# ***Conclusion***: My analysis consistently shows that discounts and marketing strategies are super effective in influencing whether customers buy or not. I'm confident about this because:
# - They had high positive coefficients in the logistic regression model.
# - They ranked top in permutation importance for the random forest model.
# - These results were consistent across different modeling approaches.
#
# *Proposed enhancement* to address the overfitting in the random forest model include: grouping some of those features with lots of unique values, or tweak the model settings to find a better balance.
